# %%
import boto3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import dask
import csv
import seaborn as sns
from pathlib import Path

# %% [markdown]
# Define an env varibale for the AWS profile and create an s3 bucket resource

# %%
# %env AWS_PROFILE = dynamodbSobCap

s3 = boto3.resource("s3")
bucket = s3.Bucket('sobesice-capital-data')
# Out:
# env: AWS_PROFILE=dynamodbSobCap

# %%
# %%timeit
obj = bucket.Object("crypto-data/bitmex/quotes/XBTUSD/2020-12-20.csv").get()
data = pd.read_csv(obj['Body'])

# %% [markdown]
# Lets see a sample of the contents in the bucket

# %%
[ob.key for i, ob in enumerate(bucket.objects.filter(Prefix='crypto-data/bitmex/')) if i < 10]
# Out:
# ['crypto-data/bitmex/quotes/BCHUSD/2020-11-17.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-18.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-19.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-20.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-21.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-22.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-23.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-24.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-25.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-26.csv']

# %% [markdown]
# Define read method bucket to pandas + other utilities.

# %%
def read_boto_obj_to_df(ticker, date, style):
    """
    Read raw csv to pandas DF
      - type quotes or trades
    """
    root_path = 'crypto-data/bitmex/'
    if style == 'quotes':
        nms = ['timestamp', 'bid', 'ask', 'bidsize', 'asksize']
    elif style == 'trans':
        nms = ['timestamp', 'ordertype', 'volume', 'price', 'ticktype']
    else:
        raise ValueError("Unknown data processing type. Supported types are 'quotes' and ' trans'.")

    path = os.path.join(root_path, style + '/', ticker + '/', date + '.csv')
    print(path)
    obj = bucket.Object(path).get()
    
    df = pd.read_csv(obj['Body'], header=None, names=nms, parse_dates=True)
    df.index = pd.to_datetime(df.timestamp)
    df = df.drop(labels='timestamp', axis=1)
    return df

def get_instruments(style='trans'):
    if style == 'quotes':
        dirty_inst_list = [key.key.split('/')[3] for key in bucket.objects.filter(Prefix='crypto-data/bitmex/quotes/')]
    elif style == 'trans':
        dirty_inst_list = [key.key.split('/')[3] for key in bucket.objects.filter(Prefix='crypto-data/bitmex/trans/')]
    else:
        raise ValueError("Supported style are limitted to 'trans' and 'quotes'.")
    unique_list = list(set(dirty_inst_list))
    return unique_list

def get_availability(instrument, style='trans', verbose=True):
    if style not in ['trans', 'quotes']:
        raise ValueError("Supported style are limitted to 'trans' and 'quotes'.")
    else:
        path = 'crypto-data/bitmex/' + style + '/' + instrument
    try:
        avail = pd.Series(pd.to_datetime([key.key.split('/')[-1].split('.')[0] for key in bucket.objects.filter(Prefix=path)]).sort_values())
        start_date = avail.iloc[0].date()
        end_date = avail.iloc[-1].date()
        missing = pd.Series(pd.date_range(start = start_date, end = end_date).difference(avail))
    except:
        raise ValueError('Symbol not available.')
    
    if verbose:
        print(f'{instrument}')
        print(f'Total days: {len(avail)}')
        print(f'Missing days: {len(missing)}, i.e., {(len(missing))/(len(missing) + len(avail)) * 100:.2f} % missing.')
        print(f'First date of data: {start_date}')
        print(f'Last date of data: {end_date}')
        
    return avail, missing

def plot_availability(symbols, style='trans', plot=True):
    "Plots the availability graph"
    df = []
    for i, sym in enumerate(symbols):
        dates, missing = get_availability(sym, style=style, verbose=False)
        dates.index = dates
        dates[:] = i
        df.append(dates)
        ret_df = pd.concat(df, axis=1, join='outer')
    ret_df.rename(columns={i:s for i, s in enumerate(symbols)}, inplace=True)
    if plot:
        ret_df.plot(marker='x', linestyle='-')
    return ret_df

# %%
all_trans_data = [s for s in get_instruments(style='trans') if s!='navidrak']
all_quotes_data = [s for s in get_instruments(style='quotes') if s!='navidrak']

# %%
dates, missing = get_availability('XBTUSD', style='trans', verbose=True)
# Out:
# XBTUSD
# Total days: 549
# Missing days: 82, i.e., 13.00 % missing.
# First date of data: 2019-04-11
# Last date of data: 2020-12-31

# %%
df1 = plot_availability(all_trans_data, style='trans', plot=True)
df2 = plot_availability(all_quotes_data, style='quotes', plot=True)

# %% [markdown]
# Visually it looks like we have quote files for all transaction files. Let's check this with a short script.

# %% [markdown]
# Furthermore, we observe that something funky is going in the futures contracts. The availability is deteriorating as time progresses. It is expected that the contract won't be traded after its expiration, however, contiguous avaialability which is not the case. Lastly all perpetuities contain uninterupted data feed with longest history available in XRPUSD, XBTUSD and ETHUSD.

# %%
futures = [word for word in all_trans_data if word.endswith('19')]
perpetuities = [word for word in all_trans_data if not word.endswith('19')]

# %%
perp_avail_t = plot_availability(perpetuities, style='trans', plot=False)
perp_avail_q = plot_availability(perpetuities, style='quotes', plot=False)
futures_avail_t = plot_availability(futures, style='trans', plot=False)

# %%
perp_avail_t.join(perp_avail_q-0.5, how='outer', lsuffix='_trades', rsuffix='_quotes').plot(title='Availability of perpetuities', marker='x', figsize=(13,7))

# %%
futures_avail_t.plot(title='Availability of futures', marker='x')

# %% [markdown]
# ## Build database

# %%
btc_trade = read_boto_obj_to_df('XBTUSD', '2020-11-20', 'trans')
# Out:
# crypto-data/bitmex/trans/XBTUSD/2020-11-20.csv

# %%
df = btc_trade

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 378892 entries, 2020-11-20 00:00:00.993000+00:00 to 2020-11-20 23:59:58.714000+00:00
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   ordertype  378892 non-null  object
#  1   volume     378892 non-null  int64
#  2   price      378892 non-null  float64
#  3   ticktype   378892 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 14.5+ MB

# %%
df.to_csv('compressedcsv.csv.gz', compression='gzip')
df.to_csv('mycsv.csv')

# %%
df.to_hdf('hdfcsv.h5', key='df', mode='w')

# %%
df.to_parquet('parquetcsv.parquet')
df.to_parquet('parquetcsv.parquet.gzip', compression='gzip')

# %%
# %%timeit
pd.read_csv('compressedcsv.csv.gz')
# Out:
# 401 ms ± 40.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
pd.read_csv('mycsv.csv')
# Out:
# 355 ms ± 36.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
pd.read_hdf('hdfcsv.h5')
# Out:
# 74.3 ms ± 15.3 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
pd.read_parquet('parquetcsv.parquet')
# Out:
# 61.5 ms ± 1.69 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
pd.read_parquet('parquetcsv.parquet.gzip')
# Out:
# 62.6 ms ± 2.96 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
btc_trade = read_boto_obj_to_df('XBTUSD', '2020-11-20', 'trans')
# Out:
# crypto-data/bitmex/trans/XBTUSD/2020-11-20.csv

# %% [markdown]
# Judging from this analysis I will stick to the Apache's parquet format.

# %%
dates[0].date()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-a5029aca2e5b> in <module>
# ----> 1 dates[0].date().tostring()
#
# AttributeError: 'datetime.date' object has no attribute 'tostring'

# %%
read_boto_obj_to_df('XBTUSD', dates[0], 'trans')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-abdeb457338a> in <module>
# ----> 1 read_boto_obj_to_df('XBTUSD', dates[0], 'trans')
#
# <ipython-input-5-6d473c70f4be> in read_boto_obj_to_df(ticker, date, style)
#      12         raise ValueError("Unknown data processing type. Supported types are 'quotes' and ' trans'.")
#      13
# ---> 14     path = os.path.join(root_path, style + '/', ticker + '/', date + '.csv')
#      15     print(path)
#      16     obj = bucket.Object(path).get()
#
# TypeError: unsupported operand type(s) for +: 'Timestamp' and 'str'

# %%
df
# Out:
#                                                  timestamp ordertype  volume  \
# timestamp
# 2020-11-20 00:00:00.993000+00:00  2020-11-20T00:00:00.993Z      Sell     640
# 2020-11-20 00:00:00.993000+00:00  2020-11-20T00:00:00.993Z      Sell    1257
# 2020-11-20 00:00:01.020000+00:00  2020-11-20T00:00:01.020Z       Buy      10
# 2020-11-20 00:00:01.026000+00:00  2020-11-20T00:00:01.026Z       Buy      11
# 2020-11-20 00:00:02.311000+00:00  2020-11-20T00:00:02.311Z      Sell    8389
# ...                                                    ...       ...     ...
# 2020-11-20 23:59:58.714000+00:00  2020-11-20T23:59:58.714Z      Sell     141
# 2020-11-20 23:59:58.714000+00:00  2020-11-20T23:59:58.714Z      Sell    1000
# 2020-11-20 23:59:58.714000+00:00  2020-11-20T23:59:58.714Z      Sell    1200
# 2020-11-20 23:59:58.714000+00:00  2020-11-20T23:59:58.714Z      Sell    1200
# 2020-11-20 23:59:58.714000+00:00  2020-11-20T23:59:58.714Z      Sell     195
#
#                                     price       ticktype
# timestamp
# 2020-11-20 00:00:00.993000+00:00  17823.5      MinusTick
# 2020-11-20 00:00:00.993000+00:00  17823.5  ZeroMinusTick
# 2020-11-20 00:00:01.020000+00:00  17824.0       PlusTick
# 2020-11-20 00:00:01.026000+00:00  17824.0   ZeroPlusTick
# 2020-11-20 00:00:02.311000+00:00  17823.5      MinusTick
# ...                                   ...            ...
# 2020-11-20 23:59:58.714000+00:00  18673.5      MinusTick
# 2020-11-20 23:59:58.714000+00:00  18673.5  ZeroMinusTick
# 2020-11-20 23:59:58.714000+00:00  18673.0      MinusTick
# 2020-11-20 23:59:58.714000+00:00  18672.5      MinusTick
# 2020-11-20 23:59:58.714000+00:00  18672.5  ZeroMinusTick
#
# [378892 rows x 5 columns]

# %%
btc_quote = read_boto_obj_to_df('XBTUSD', '2020-11-20', 'quotes')
# Out:
# crypto-data/bitmex/quotes/XBTUSD/2020-11-20.csv

# %%
start_time = btc_quote.index[0]
end_time = start_time + pd.Timedelta('100s')
btc_quote_slice = btc_quote[(btc_quote.index >= start_time) & (btc_quote.index<=end_time)]

# %%
btc_trade[(btc_trade.index >= start_time) & (btc_trade.index<=end_time)]
# Out:
#                                                  timestamp ordertype  volume  \
# timestamp
# 2020-11-20 00:00:00.993000+00:00  2020-11-20T00:00:00.993Z      Sell     640
# 2020-11-20 00:00:00.993000+00:00  2020-11-20T00:00:00.993Z      Sell    1257
# 2020-11-20 00:00:01.020000+00:00  2020-11-20T00:00:01.020Z       Buy      10
# 2020-11-20 00:00:01.026000+00:00  2020-11-20T00:00:01.026Z       Buy      11
#
#                                     price       ticktype
# timestamp
# 2020-11-20 00:00:00.993000+00:00  17823.5      MinusTick
# 2020-11-20 00:00:00.993000+00:00  17823.5  ZeroMinusTick
# 2020-11-20 00:00:01.020000+00:00  17824.0       PlusTick
# 2020-11-20 00:00:01.026000+00:00  17824.0   ZeroPlusTick

# %%
btc_quote.join(btc_trade, how='inner', lsuffix='_left', rsuffix='_right').shape
# Out:
# (379792, 10)

# %%
btc_trade.index
# Out:
# DatetimeIndex(['2020-11-20 00:00:00.993000+00:00',
#                '2020-11-20 00:00:00.993000+00:00',
#                '2020-11-20 00:00:01.020000+00:00',
#                '2020-11-20 00:00:01.026000+00:00',
#                '2020-11-20 00:00:02.311000+00:00',
#                '2020-11-20 00:00:02.317000+00:00',
#                '2020-11-20 00:00:02.329000+00:00',
#                '2020-11-20 00:00:02.342000+00:00',
#                '2020-11-20 00:00:02.342000+00:00',
#                '2020-11-20 00:00:02.342000+00:00',
#                ...
#                '2020-11-20 23:59:52.607000+00:00',
#                '2020-11-20 23:59:58.714000+00:00',
#                '2020-11-20 23:59:58.714000+00:00',
#                '2020-11-20 23:59:58.714000+00:00',
#                '2020-11-20 23:59:58.714000+00:00',
#                '2020-11-20 23:59:58.714000+00:00',
#                '2020-11-20 23:59:58.714000+00:00',
#                '2020-11-20 23:59:58.714000+00:00',
#                '2020-11-20 23:59:58.714000+00:00',
#                '2020-11-20 23:59:58.714000+00:00'],
#               dtype='datetime64[ns, UTC]', name='timestamp', length=378892, freq=None)

# %%
btc_quote.join(btc_trade, how='outer')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-f4d45736131f> in <module>
# ----> 1 btc_quote.join(btc_trade, how='outer',)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7873         """
#    7874         return self._join_compat(
# -> 7875             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7876         )
#    7877
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7896                 right_index=True,
#    7897                 suffixes=(lsuffix, rsuffix),
# -> 7898                 sort=sort,
#    7899             )
#    7900         else:
#
# /usr/local/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# /usr/local/lib/python3.7/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     669
#     670         llabels, rlabels = _items_overlap_with_suffix(
# --> 671             self.left._info_axis, self.right._info_axis, self.suffixes
#     672         )
#     673
#
# /usr/local/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2094
#    2095     if not lsuffix and not rsuffix:
# -> 2096         raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2097
#    2098     def renamer(x, suffix):
#
# ValueError: columns overlap but no suffix specified: Index(['timestamp'], dtype='object')

# %%
merged_btc_outter = btc_quote.join(btc_trade, how='outer', lsuffix='_left', rsuffix='_right')
merged_btc_inner = btc_quote.join(btc_trade, how='inner', lsuffix='_left', rsuffix='_right')
print(btc_trade.shape)
print(btc_quote.shape)
print(merged.shape)
print(merged_btc_outter[~pd.isna(merged_btc_outter.timestamp_right)].shape)
# Out:
# (378892, 5)
# (2263566, 5)
# (2486118, 10)
# (380051, 10)

# %%
str(Path.home())
# Out:
# '/Users/mmark'

# %%
merged_btc_outter.head(50)
# Out:
#                                             timestamp_left      bid      ask  \
# timestamp
# 2020-11-20 00:00:00.943000+00:00  2020-11-20T00:00:00.943Z  17823.5  17824.0
# 2020-11-20 00:00:00.949000+00:00  2020-11-20T00:00:00.949Z  17823.5  17824.0
# 2020-11-20 00:00:00.951000+00:00  2020-11-20T00:00:00.951Z  17823.5  17824.0
# 2020-11-20 00:00:00.956000+00:00  2020-11-20T00:00:00.956Z  17823.5  17824.0
# 2020-11-20 00:00:00.962000+00:00  2020-11-20T00:00:00.962Z  17823.5  17824.0
# 2020-11-20 00:00:00.993000+00:00  2020-11-20T00:00:00.993Z  17823.5  17824.0
# 2020-11-20 00:00:00.993000+00:00  2020-11-20T00:00:00.993Z  17823.5  17824.0
# 2020-11-20 00:00:00.996000+00:00  2020-11-20T00:00:00.996Z  17823.5  17824.0
# 2020-11-20 00:00:01.014000+00:00  2020-11-20T00:00:01.014Z  17823.5  17824.0
# 2020-11-20 00:00:00.951000+00:00      NaN            NaN
# 2020-11-20 00:00:00.956000+00:00      NaN            NaN
# 2020-11-20 00:00:00.962000+00:00      NaN            NaN
# 2020-11-20 00:00:00.993000+00:00  17823.5      MinusTick
# 2020-11-20 00:00:00.993000+00:00  17823.5  ZeroMinusTick
# 2020-11-20 00:00:00.996000+00:00      NaN            NaN
# 2020-11-20 00:00:01.014000+00:00      NaN            NaN
# 2020-11-20 00:00:01.020000+00:00  17824.0       PlusTick
# 2020-11-20 00:00:01.026000+00:00  17824.0   ZeroPlusTick
# 2020-11-20 00:00:01.044000+00:00      NaN            NaN
# 2020-11-20 00:00:01.050000+00:00      NaN            NaN
# 2020-11-20 00:00:01.051000+00:00      NaN            NaN
# 2020-11-20 00:00:01.052000+00:00      NaN            NaN
# 2020-11-20 00:00:01.116000+00:00      NaN            NaN
# 2020-11-20 00:00:01.149000+00:00      NaN            NaN
# 2020-11-20 00:00:01.172000+00:00      NaN            NaN
# 2020-11-20 00:00:01.179000+00:00      NaN            NaN
# 2020-11-20 00:00:01.180000+00:00      NaN            NaN
# 2020-11-20 00:00:01.187000+00:00      NaN            NaN
# 2020-11-20 00:00:01.203000+00:00      NaN            NaN
# 2020-11-20 00:00:01.328000+00:00      NaN            NaN
# 2020-11-20 00:00:01.627000+00:00      NaN            NaN
# 2020-11-20 00:00:01.653000+00:00      NaN            NaN
# 2020-11-20 00:00:01.656000+00:00      NaN            NaN
# 2020-11-20 00:00:01.967000+00:00      NaN            NaN
# 2020-11-20 00:00:02.252000+00:00      NaN            NaN
# 2020-11-20 00:00:02.281000+00:00      NaN            NaN
# 2020-11-20 00:00:02.288000+00:00      NaN            NaN
# 2020-11-20 00:00:02.301000+00:00      NaN            NaN
# 2020-11-20 00:00:02.311000+00:00  17823.5      MinusTick
# 2020-11-20 00:00:02.317000+00:00  17824.0       PlusTick
# 2020-11-20 00:00:02.329000+00:00  17824.0   ZeroPlusTick
# 2020-11-20 00:00:02.335000+00:00      NaN            NaN
# 2020-11-20 00:00:02.338000+00:00      NaN            NaN
# 2020-11-20 00:00:02.339000+00:00      NaN            NaN
# 2020-11-20 00:00:02.342000+00:00  17823.5      MinusTick
# 2020-11-20 00:00:02.342000+00:00  17823.5  ZeroMinusTick
# 2020-11-20 00:00:02.342000+00:00  17823.5  ZeroMinusTick
# 2020-11-20 00:00:02.342000+00:00  17823.5  ZeroMinusTick
# 2020-11-20 00:00:02.347000+00:00      NaN            NaN
# 2020-11-20 00:00:02.349000+00:00  17824.0       PlusTick
# 2020-11-20 00:00:02.352000+00:00      NaN            NaN
# 2020-11-20 00:00:02.354000+00:00      NaN            NaN
# 2020-11-20 00:00:02.377000+00:00  17823.5      MinusTick
# 2020-11-20 00:00:02.377000+00:00  17823.5  ZeroMinusTick
# 2020-11-20 00:00:02.377000+00:00  17823.5  ZeroMinusTick
# 2020-11-20 00:00:02.377000+00:00  17822.5      MinusTick
# 2020-11-20 00:00:02.384000+00:00  17824.0       PlusTick

# %%
btc_quote_slice[['bidsize', 'asksize']].plot(drawstyle="steps-post")
plt.yscale('log')

# %%
os.geth

# %%
def bin_index(df, bin_size):
    remainder = btc.price%bin_size
    df[remainder!=0] +

# %%
cut, bins = pd.cut(slice1.price, 15, retbins=True)

# %%
slice1.groupby(pd.cut(slice1.price, 15)).sum().volume
# Out:
# price
# (17805.864, 17815.1]    1006937
# (17815.1, 17824.2]       394322
# (17824.2, 17833.3]       607847
# (17833.3, 17842.4]       600754
# (17842.4, 17851.5]      1260373
# (17851.5, 17860.6]      1513516
# (17860.6, 17869.7]       404594
# (17869.7, 17878.8]      1101847
# (17878.8, 17887.9]      6160948
# (17887.9, 17897.0]      6734039
# (17897.0, 17906.1]      4689832
# (17906.1, 17915.2]      5465378
# (17915.2, 17924.3]      6196717
# (17924.3, 17933.4]      1510309
# (17933.4, 17942.5]      4002174
# Name: volume, dtype: int64

# %%
profile = slice1.groupby(pd.cut(slice1.price, 20)).sum().volume
profile
# Out:
# price
# (17805.864, 17812.825]     858610
# (17812.825, 17819.65]      256331
# (17819.65, 17826.475]      428213
# (17826.475, 17833.3]       465952
# (17833.3, 17840.125]       345523
# (17840.125, 17846.95]      411602
# (17846.95, 17853.775]     1566202
# (17853.775, 17860.6]      1051316
# (17860.6, 17867.425]       173736
# (17867.425, 17874.25]      596061
# (17874.25, 17881.075]     2370588
# (17881.075, 17887.9]      4527004
# (17887.9, 17894.725]      5314260
# (17894.725, 17901.55]     5131434
# (17901.55, 17908.375]     2608466
# (17908.375, 17915.2]      3835089
# (17915.2, 17922.025]      6025971
# (17922.025, 17928.85]      952781
# (17928.85, 17935.675]     2903459
# (17935.675, 17942.5]      1826989
# Name: volume, dtype: int64

# %%
profile.plot.bar()

# %%
plt.plot(slice1.price)
plt.barplot(profile)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-2620675fc364> in <module>
#       1 plt.plot(slice1.price)
# ----> 2 plt.barplot(profile)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'barplot'

# %%
plt.bar()

# %%
slice1.price.plot()
plt.axhline(bins[9])

# %%
plt.plot(slice1.groupby(pd.cut(slice1.price, 10)).sum().volume)
# Out:
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_base.py:348: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]

# %%
slice1 = btc[btc.index < btc.index[0] + pd.Timedelta('30min')]

# %%
slice1.groupby('price').volume.sum().plot()

# %%
ticker = BCHUSD
'crypto-data/bitmex/quotes/' + ticker +

# %%
def get_instruments(style='trans'):
    if style == 'quotes':
        dirty_inst_list = [key.key.split('/')[3] for key in bucket.objects.filter(Prefix='crypto-data/bitmex/quotes/')]
    elif style == 'trans':
        dirty_inst_list = [key.key.split('/')[3] for key in bucket.objects.filter(Prefix='crypto-data/bitmex/trans/')]
    else:
        raise ValueError("Supported style are limitted to 'trans' and 'quotes'.")
    unique_list = list(set(dirty_inst_list))
    return unique_list

# %%
def get_availability(instrument, style='trans', verbose=True):
    if style not in ['trans', 'quotes']:
        raise ValueError("Supported style are limitted to 'trans' and 'quotes'.")
    else:
        path = 'crypto-data/bitmex/' + style + '/' + instrument
    avail = pd.Series(pd.to_datetime([key.key.split('/')[-1].split('.')[0] for key in bucket.objects.filter(Prefix=path)]).sort_values())
    start_date = avail.iloc[0].date()
    end_date = avail.iloc[-1].date()
    missing = pd.Series(pd.date_range(start = start_date, end = end_date).difference(avail))
    
    if verbose:
        print(f'Total days: {len(avail)}')
        print(f'Missing days: {len(missing)}, i.e., {(len(missing))/(len(missing) + len(avail)) * 100:.2f} % missing.')
        print(f'First date of data: {start_date}')
        print(f'Last date of data: {end_date}')
        
    return avail, missing

# %%
dates, missing = get_availability('BCH', 'trans', verbose=True)
# Out:
# Total days: 155
# Missing days: 467, i.e., 75.08 % missing.
# First date of data: 2019-04-11
# Last date of data: 2020-12-22

# %%
dates.iloc[-1] - dates.iloc[0]
# Out:
# Timedelta('621 days 00:00:00')

# %%
pd.date_range(start = '2019-04-11', end = ' 2020-12-22' ).difference(dates)
# Out:
# (467,)

# %%
missing
# Out:
# DatetimeIndex(['2019-07-01', '2019-07-03', '2019-07-04', '2019-07-06',
#                '2019-07-10', '2019-07-13', '2019-07-15', '2019-07-18',
#                '2019-07-20', '2019-07-21',
#                ...
#                '2020-11-07', '2020-11-08', '2020-11-09', '2020-11-10',
#                '2020-11-11', '2020-11-12', '2020-11-13', '2020-11-14',
#                '2020-11-15', '2020-11-16'],
#               dtype='datetime64[ns]', length=467, freq=None)

# %%
dates[dates.diff().dt.days != 1] - pd.Timedelta(days=1)
# Out:
# 0     2019-04-10
# 81    2019-07-01
# 82    2019-07-04
# 83    2019-07-06
# 86    2019-07-10
# 88    2019-07-13
# 89    2019-07-15
# 91    2019-07-18
# 92    2019-07-22
# 93    2019-07-25
# 94    2019-07-29
# 99    2019-08-04
# 100   2019-08-06
# 102   2019-08-11
# 103   2019-08-15
# 104   2019-08-19
# 107   2019-08-26
# 109   2019-09-02
# 112   2019-09-08
# 113   2019-09-18
# 114   2019-09-23
# 116   2019-09-29
# 117   2019-10-01
# 118   2019-10-09
# 119   2020-11-16
# dtype: datetime64[ns]

# %%
dates.iloc[115:121]
# Out:
# 115   2019-09-25
# 116   2019-09-30
# 117   2019-10-02
# 118   2019-10-10
# 119   2020-11-17
# 120   2020-11-18
# dtype: datetime64[ns]

# %%
dates.astype('ordinal')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-175-d3693a50d9fa> in <module>
# ----> 1 dates.astype('ordinal')
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/extension.py in astype(self, dtype, copy)
#     273             return self
#     274
# --> 275         new_values = self._data.astype(dtype, copy=copy)
#     276
#     277         # pass copy=False because any copying will be done in the
#
# /usr/local/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in astype(self, dtype, copy)
#     576         #   --> period
#     577         # DatetimeLikeArrayMixin Super handles the rest.
# --> 578         dtype = pandas_dtype(dtype)
#     579
#     580         if is_datetime64_ns_dtype(dtype) and not is_dtype_equal(dtype, self.dtype):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/dtypes/common.py in pandas_dtype(dtype)
#    1761     # raise a consistent TypeError if failed
#    1762     try:
# -> 1763         npdtype = np.dtype(dtype)
#    1764     except SyntaxError as err:
#    1765         # np.dtype uses `eval` which can raise SyntaxError
#
# TypeError: data type "ordinal" not understood

# %%
dates
# Out:
# DatetimeIndex(['2019-04-11', '2019-04-12', '2019-04-13', '2019-04-14',
#                '2019-04-15', '2019-04-16', '2019-04-17', '2019-04-18',
#                '2019-04-19', '2019-04-20',
#                ...
#                '2020-12-13', '2020-12-14', '2020-12-15', '2020-12-16',
#                '2020-12-17', '2020-12-18', '2020-12-19', '2020-12-20',
#                '2020-12-21', '2020-12-22'],
#               dtype='datetime64[ns]', length=155, freq=None)

# %%
len(dates)
# Out:
# 35

# %%
get_instruments('quotes')
# Out:
# ['XBTUSD', 'LTCUSD', 'LINKUSDT', 'XRPUSD', 'ETHUSD', 'BCHUSD']

# %%
get_instruments('trans')
# Out:
# ['EOSM19',
#  'BCHM19',
#  'XRPM19',
#  'ADAM19',
#  'TRXM19',
#  'LTCM19',
#  'navidrak',
#  'XBTUSD',
#  'LTCUSD',
#  'LINKUSDT',
#  'XRPUSD',
#  'ETHUSD',
#  'BCHUSD']

# %%
a = get_instruments('quotes')

# %%
a[0].split('/')[3]
# Out:
# 'BCHUSD'

# %%
a[0].key
# Out:
# 'crypto-data/bitmex/trans/ADAM19/2019-04-11.csv'

# %%
def check_availablility(intruments):
    list(bucket.objects.filter(Prefix='crypto-data/bitmex/quotes/' + 'ticker'))

# %%
[ob.key for ob in bucket.objects.filter(Prefix='crypto-data/bitmex/')]
# Out:
# ['crypto-data/bitmex/quotes/BCHUSD/2020-11-17.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-18.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-19.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-20.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-21.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-22.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-23.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-24.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-25.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-26.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-27.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-28.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-29.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-11-30.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-12-01.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-12-02.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-12-03.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-12-04.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-12-05.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-12-06.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-12-07.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-12-08.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-12-09.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-12-10.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-12-11.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-12-12.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-12-13.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-12-14.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-12-15.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-12-16.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-12-17.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-12-18.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-12-19.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-12-20.csv',
#  'crypto-data/bitmex/quotes/BCHUSD/2020-12-21.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-04.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-05.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-06.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-07.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-08.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-09.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-10.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-11.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-12.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-13.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-14.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-15.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-16.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-17.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-18.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-19.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-20.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-21.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-22.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-23.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-24.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-25.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-26.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-27.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-28.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-29.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-30.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-10-31.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-01.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-02.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-03.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-04.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-05.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-06.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-07.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-08.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-09.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-10.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-11.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-12.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-13.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-14.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-15.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-16.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-17.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-18.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-19.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-20.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-21.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-22.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-23.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-24.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-25.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-26.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-27.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-28.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-29.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-11-30.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-01.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-02.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-03.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-04.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-05.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-06.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-07.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-08.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-09.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-10.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-11.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-12.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-13.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-14.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-15.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-16.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-17.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-18.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-19.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-20.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-21.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-22.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-23.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-24.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-25.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-26.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-27.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-28.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-29.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-30.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2019-12-31.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-01.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-02.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-03.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-04.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-05.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-06.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-07.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-08.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-09.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-10.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-11.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-12.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-13.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-14.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-15.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-16.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-17.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-18.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-19.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-20.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-21.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-22.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-23.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-24.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-25.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-26.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-27.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-28.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-29.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-30.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-01-31.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-01.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-02.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-03.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-04.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-05.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-06.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-07.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-08.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-09.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-10.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-11.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-12.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-13.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-14.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-15.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-16.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-17.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-18.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-19.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-20.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-21.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-22.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-23.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-24.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-25.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-26.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-27.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-28.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-02-29.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-01.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-02.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-03.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-04.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-05.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-06.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-07.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-08.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-09.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-10.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-11.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-12.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-13.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-14.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-15.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-16.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-17.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-18.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-19.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-20.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-21.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-22.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-23.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-24.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-25.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-26.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-27.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-28.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-29.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-30.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-03-31.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-01.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-02.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-03.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-04.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-05.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-06.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-07.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-08.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-09.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-10.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-11.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-12.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-13.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-14.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-15.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-16.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-17.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-18.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-19.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-20.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-21.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-22.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-23.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-24.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-25.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-26.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-27.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-28.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-29.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-04-30.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-01.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-02.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-03.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-04.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-05.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-06.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-07.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-08.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-09.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-10.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-11.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-12.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-13.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-14.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-15.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-16.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-17.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-18.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-19.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-20.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-21.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-22.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-23.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-24.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-25.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-05-26.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-08-17.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-08-18.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-08-19.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-08-20.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-08-21.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-08-22.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-08-23.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-08-24.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-08-25.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-08-26.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-08-27.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-08-28.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-08-29.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-08-30.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-08-31.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-01.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-02.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-03.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-04.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-05.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-06.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-07.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-08.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-09.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-10.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-11.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-12.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-13.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-14.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-15.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-16.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-17.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-18.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-19.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-20.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-21.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-22.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-23.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-24.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-25.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-26.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-27.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-28.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-29.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-09-30.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-01.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-02.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-03.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-04.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-05.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-06.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-07.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-08.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-09.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-10.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-11.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-12.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-13.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-14.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-15.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-16.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-17.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-18.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-19.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-20.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-21.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-22.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-23.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-24.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-25.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-26.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-27.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-28.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-29.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-30.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-10-31.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-01.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-02.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-03.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-04.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-05.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-06.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-07.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-08.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-09.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-10.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-11.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-12.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-13.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-14.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-15.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-16.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-17.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-18.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-19.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-20.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-21.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-22.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-23.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-24.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-25.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-26.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-27.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-28.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-29.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-11-30.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-12-01.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-12-02.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-12-03.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-12-04.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-12-05.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-12-06.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-12-07.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-12-08.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-12-09.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-12-10.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-12-11.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-12-12.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-12-13.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-12-14.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-12-15.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-12-16.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-12-17.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-12-18.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-12-19.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-12-20.csv',
#  'crypto-data/bitmex/quotes/ETHUSD/2020-12-21.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-11-17.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-11-18.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-11-19.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-11-20.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-11-21.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-11-22.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-11-23.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-11-24.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-11-25.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-11-26.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-11-27.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-11-28.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-11-29.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-11-30.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-12-01.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-12-02.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-12-03.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-12-04.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-12-05.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-12-06.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-12-07.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-12-08.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-12-09.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-12-10.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-12-11.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-12-12.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-12-13.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-12-14.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-12-15.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-12-16.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-12-17.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-12-18.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-12-19.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-12-20.csv',
#  'crypto-data/bitmex/quotes/LINKUSDT/2020-12-21.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-11-17.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-11-18.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-11-19.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-11-20.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-11-21.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-11-22.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-11-23.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-11-24.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-11-25.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-11-26.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-11-27.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-11-28.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-11-29.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-11-30.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-12-01.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-12-02.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-12-03.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-12-04.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-12-05.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-12-06.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-12-07.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-12-08.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-12-09.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-12-10.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-12-11.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-12-12.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-12-13.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-12-14.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-12-15.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-12-16.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-12-17.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-12-18.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-12-19.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-12-20.csv',
#  'crypto-data/bitmex/quotes/LTCUSD/2020-12-21.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-04.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-05.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-06.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-07.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-08.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-09.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-10.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-11.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-12.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-13.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-14.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-15.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-16.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-17.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-18.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-19.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-20.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-21.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-22.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-23.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-24.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-25.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-26.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-27.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-28.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-29.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-30.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-10-31.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-01.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-02.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-03.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-04.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-05.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-06.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-07.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-08.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-09.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-10.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-11.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-12.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-13.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-14.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-15.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-16.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-17.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-18.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-19.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-20.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-21.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-22.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-23.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-24.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-25.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-26.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-27.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-28.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-29.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-11-30.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-12-01.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-12-02.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-12-03.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-12-04.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2019-12-05.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-01-19.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-01-20.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-01-21.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-01-22.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-01-23.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-01-24.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-01-25.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-01-26.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-01-27.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-01-28.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-01-29.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-01-30.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-01-31.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-01.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-02.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-03.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-04.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-05.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-06.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-07.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-08.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-09.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-10.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-11.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-12.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-13.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-14.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-15.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-16.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-17.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-18.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-19.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-20.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-21.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-22.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-23.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-24.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-25.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-26.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-27.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-28.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-02-29.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-01.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-02.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-03.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-04.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-05.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-06.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-07.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-08.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-09.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-10.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-11.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-12.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-13.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-14.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-15.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-16.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-17.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-18.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-19.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-20.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-21.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-22.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-23.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-24.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-25.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-26.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-27.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-28.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-29.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-30.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-03-31.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-01.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-02.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-03.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-04.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-05.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-06.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-07.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-08.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-09.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-10.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-11.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-12.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-13.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-14.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-15.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-16.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-17.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-18.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-19.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-20.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-21.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-22.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-23.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-24.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-25.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-26.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-27.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-28.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-29.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-04-30.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-01.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-02.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-03.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-04.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-05.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-06.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-07.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-08.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-09.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-10.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-11.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-12.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-13.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-14.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-15.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-16.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-17.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-18.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-19.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-20.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-21.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-22.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-23.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-24.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-25.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-05-26.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-08-17.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-08-18.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-08-19.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-08-20.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-08-21.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-08-22.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-08-23.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-08-24.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-08-25.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-08-26.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-08-27.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-08-28.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-08-29.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-08-30.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-08-31.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-01.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-02.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-03.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-04.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-05.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-06.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-07.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-08.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-09.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-10.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-11.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-12.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-13.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-14.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-15.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-16.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-17.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-18.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-19.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-20.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-21.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-22.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-23.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-24.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-25.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-26.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-27.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-28.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-29.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-09-30.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-01.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-02.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-03.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-04.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-05.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-06.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-07.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-08.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-09.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-10.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-11.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-12.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-13.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-14.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-15.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-16.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-17.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-18.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-19.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-20.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-21.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-22.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-23.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-24.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-25.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-26.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-27.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-28.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-29.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-30.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-10-31.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-01.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-02.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-03.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-04.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-05.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-06.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-07.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-08.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-09.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-10.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-11.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-12.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-13.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-14.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-15.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-16.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-17.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-18.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-19.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-20.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-21.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-22.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-23.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-24.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-25.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-26.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-27.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-28.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-29.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-11-30.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-12-01.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-12-02.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-12-03.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-12-04.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-12-05.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-12-06.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-12-07.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-12-08.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-12-09.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-12-10.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-12-11.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-12-12.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-12-13.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-12-14.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-12-15.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-12-16.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-12-17.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-12-18.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-12-19.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-12-20.csv',
#  'crypto-data/bitmex/quotes/XBTUSD/2020-12-21.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-04-24.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-04-25.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-04-26.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-04-27.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-04-28.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-04-29.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-04-30.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-01.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-02.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-03.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-04.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-05.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-06.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-07.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-08.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-09.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-10.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-11.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-12.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-13.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-14.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-15.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-16.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-17.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-18.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-19.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-20.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-21.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-22.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-23.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-24.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-25.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-05-26.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-08-17.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-08-18.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-08-19.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-08-20.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-08-21.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-08-22.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-08-23.csv',
#  'crypto-data/bitmex/quotes/XRPUSD/2020-08